# %%
import os
from google.cloud import translate
from google.cloud import translate_v2 as translate
import csv

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r"E:\Selise\RiQS\Translation\TranslationAPI\Google_Cloud_Key.json"
translate_client=translate.Client()

# %%
German_List = []
with open('German.csv', newline='') as inputfile:
    for row in csv.reader(inputfile):
        German_List.append(row[0])

def translate_list(lang_list, lang):
    target=lang
    translated_lang=[]
    for text in lang_list:
        output=translate_client.translate(text,lang)
        translated_lang.append(output)


    return translated_lang

# %%
German_List
# Out:
# ['Kategorie hinzufÃ¼gen',
#  'zeigt Kategorien und Unterkategorien',
#  'Kategorie erstellen',
#  'Bitte geben Sie die notwendigen Informationen zum HinzufÃ¼gen von Kategorien oder Unterkategorien fÃ¼r',
#  'Kategoriename',
#  'Kontrollgruppe',
#  'ausfÃ¼hrende Gruppe',
#  'Gruppe zuweisen',
#  'Bitte ordnen Sie die Gruppenmitglieder fÃ¼r diese Kategorie zu.',
#  'Kategorie speichern',
#  'Abbrechen',
#  'Name der Unterkategorie',
#  'Unterkategorie',
#  'Unterkategorie hinzufÃ¼gen',
#  'mehr',
#  'Kategorien anzeigen',
#  'Unter-Kategorien',
#  'Keine Unterkategorie hinzugefÃ¼gt',
#  'Zeigt die Mitglieder der prÃ¼fenden Gruppe fÃ¼r alle Kategorie',
#  'Mitglieder der prÃ¼fenden Gruppe',
#  'Mitglied der ausfÃ¼hrenden Gruppe',
#  'Anzeige aller Unterkategorien von',
#  'Anzeige der ausfÃ¼rhenden Gruppenmitglieder',
#  'Zeigt die Mitglieder der ausfÃ¼hrenden Gruppe fÃ¼r diese Unterkategorie',
#  'Zeigt die Mitglieder der ausfÃ¼hrenden Gruppe der Kategorie an',
#  'Zeigt die Mitglieder der prÃ¼fenden Gruppe der Kategorie',
#  'Kein Mitglieder der ausfÃ¼hrenden Gruppe hinzugefÃ¼gt',
#  'Kein Mitglied der prÃ¼fenden Gruppe hinzugefÃ¼gt',
#  'Keine Kategorie fÃ¼r diesen Kunden hinzugefÃ¼gt.',
#  'Kategorie aktualisieren',
#  'Kategorie aktualisieren',
#  'Mandantenkategorie erfolgreich angelegt',
#  'Erstellen der Kundenkategorie fehlgeschlagen',
#  'Kundenkategorie erfolgreich aktualisiert',
#  'Update der Kundenkategorie fehlgeschlagen',
#  'Organisation',
#  'Verwalten Sie Ihre Organisation',
#  'Organisation suchen',
#  'Filter',
#  'Suche',
#  'Organsiation anlegen',
#  'Name der Organisation',
#  'Organisation',
#  'Organisations-Nummer',
#  'Kontakt Information',
#  'Erstellt am',
#  'E-Mail',
#  'Passwort',
#  'Sprache',
#  'Passwort vergessen?',
#  'E-Mail eingeben',
#  'Telefon',
#  'Strasse',
#  'Strassen Nr.',
#  'Stadt',
#  'Land',
#  'Abbrechen',
#  'Speichern',
#  'Postleitzahl',
#  'Adresse & Kontaktinformationen',
#  'Logo Organisation',
#  'Web-Seiten-URL',
#  'Software',
#  'Betriebssystem',
#  'Mitgliedschaft',
#  'Allgemeine Informationen',
#  'Information zur Organisation',
#  'Erstellen Sie eine Organisation fÃ¼r Ihre Anwendung.',
#  'Organisation hinzufÃ¼gen',
#  'Organisation aktualisieren',
#  'Detail',
#  'Kategorien',
#  'Training',
#  'Bitte Lieferanten hinzufÃ¼gen',
#  'Lieferanten hinzufÃ¼gen',
#  'Lieferanten Gruppe A',
#  'Lieferanten Gruppe B',
#  'Lieferanten Gruppe C',
#  'Noch kein Lieferant hinzugefÃ¼gt',
#  'Lieferant hinzufÃ¼gen',
#  'Bitte fÃ¼gen Sie den Lieferanten fÃ¼r Ihre Organisation hinzu.',
#  'Lieferant hinzufÃ¼gen',
#  'Lieferanteninformationen aktualisieren',
#  'Name',
#  'Lieferanten Kategorie',
#  'Lieferanten Gruppe C',
#  'Ignorieren',
#  'Ja',
#  'Nein',
#  'Wollen Sie wirklich lÃ¶schen?',
#  'Lieferant erfolgreich hinzugefÃ¼gt.',
#  'HinzufÃ¼gen des Lieferanten fehlgeschlagen',
#  'Lieferant erfolgreich aktualisiert',
#  'Aktualisierung des Lieferanten fehlgeschlagen',
#  'Lieferant erfolgreich gelÃ¶scht.',
#  'Lieferant lÃ¶schen fehlgeschlagen',
#  'Organisation erfolgreich angelegt',
#  'Organisation anlegen fehlgeschlagen',
#  'Organisation erfolgreich aktualisiert',
#  'Organisation Aktualisierung fehlgeschlagen',
#  'Kontaktperson',
#  'Name der Kontaktperson',
#  'Telefonnummer',
#  'Kontaktdaten',
#  'Bitte geben Sie die Informationen der Kontaktperson an.',
#  'Suche Ã¼ber Organisationsname, Kontaktdaten und Kundennummer',
#  'Suche nach Organisationsname, Kontaktdaten & Nummer',
#  'Organisationsdaten bearbeiten',
#  'erstellen',
#  'Zugang zur Anwendung',
#  'Bild ziehen und ablegen oder auswÃ¤hlen',
#  'Maximale DateigrÃ¶sse',
#  'Adresse eingeben',
#  'Dokument',
#  'Neu',
#  'Ordner',
#  'Datei-Upload',
#  'zuweisen',
#  'umbenennen',
#  'herunterladen',
#  'entfernen',
#  'Farbe Ã¤ndern',
#  'Suche',
#  'SCHLÃœSSEL_VERMISST',
#  'Listenansicht',
#  'Rasteransicht',
#  'Dateien hier ablegen',
#  'oder benutzen Sie die SchaltflÃ¤che "Neu"',
#  'freigegebene Ordner',
#  'Ordner',
#  'Freigegebene Dateien',
#  'Dateien',
#  'Name',
#  'Typ',
#  'GrÃ¶sse',
#  'Erstellt am',
#  'Name des Ordners',
#  'abbrechen',
#  'erstellen',
#  'Rolle auswÃ¤hlen',
#  'bestimmte Person auswÃ¤hlen',
#  'Keine Person hinzugefÃ¼gt',
#  'WÃ¤hlen Sie aus den vorhandenen',
#  'Dateien auf dieses Feld ziehen und loslassen, um sie hochzuladen auf:',
#  'Mein Laufwerk',
#  'Hochladen',
#  'Upload(s) abgeschlossen',
#  'Fehler beim Hochladen der Datei',
#  'Neuer Ordner',
#  'Ornder erfolgreich erstellt',
#  'Die Erstellung des Ordners ist fehlgeschlagen. Versuchen Sie es spÃ¤ter noch einmal.',
#  'Umbenennen',
#  'Umbenennen',
#  'freigegebene Datei',
#  'erfolgreich umbenannt',
#  'erfolgreich entfernt',
#  'Fehler beim Hertunterladen der Datei',
#  'Etwas hat nicht geklappt. Bitte nochmals versuchen',
#  'Organisation',
#  'Bitte wÃ¤hlen Sie die Organisation, der Sie zuweisen mÃ¶chten',
#  'Dokumente hochladen, verwalten und freigeben.',
#  'Dokumente hochladen, verwalten, freigeben',
#  'Datei',
#  'Bitte geben Sie Ihrem Ordner einen Namen',
#  'erfolgreich entfernt',
#  'erfolgreich umbenannt',
#  'Keine Dateien',
#  'maximale DateigrÃ¶ÃŸe Ã¼berschritten',
#  'Dateityp wird nicht unterstÃ¼tzt',
#  'Organisation auswÃ¤hlen',
#  'Organisation auswÃ¤hlen',
#  'Mitglieder auswÃ¤hlen',
#  'Keine Datei oder kein Ordner ausgewÃ¤hlt',
#  'zugewiesen an',
#  'Details anzeigen',
#  'Datei',
#  'Infos',
#  'erstellt von',
#  'berechtigte Benutzer',
#  'GerÃ¤te-Bewirtschaftung',
#  'Suche nach Standort oder GerÃ¤t',
#  'Filter',
#  'HinzufÃ¼gen, Verwaltungen von GerÃ¤ten und Standorten',
#  'GerÃ¤te aktualisieren',
#  'GerÃ¤t hinzufÃ¼gen',
#  'Standort hinzufÃ¼gen',
#  'Standorte',
#  'Bitte wÃ¤hlen Sie den Standort aus, um die GerÃ¤teliste zu sehen',
#  'GerÃ¤te',
#  'Zeigt alle GerÃ¤te des ausgewÃ¤hlten Standortes',
#  'Name',
#  'weitere hinzufÃ¼gen',
#  'verwerfen',
#  'hinzufÃ¼gen',
#  'GerÃ¤t hinzufÃ¼gen',
#  'GerÃ¤te aktualisieren',
#  'Bitte die notwendigen Informationen fÃ¼r das HinzufÃ¼gen des GerÃ¤tes eingeben',
#  'Name des Standorts',
#  'Kategorie',
#  'Unter-Kategorie',
#  'Thema',
#  'Hersteller',
#  'zusÃ¤tzliche Informationen',
#  'Bitte fÃ¼gen Sie die erforderlichen Felder fÃ¼r dieses GerÃ¤t hinzu',
#  'zusÃ¤tzliches Feld',
#  'Titel',
#  'Beschreibung',
#  'Ein weiteres Feld hinzufÃ¼gen',
#  'Bitte wÃ¤hlen Sie das Installationsdatum',
#  'Datum',
#  'Kontaktdaten',
#  'Kontakt fÃ¼r Wartung',
#  'E-Mail Adresse',
#  'Telefon',
#  'Bemerkungen',
#  'Organisation',
#  'aktualisieren',
#  'erstellt am',
#  'Details',
#  'Wartung',
#  'EigentÃ¼mer',
#  'Standort',
#  'Datum der Installation',
#  'Letzte Wartung',
#  'NÃ¤chste Wartung',
#  'Datei hinzufÃ¼gen',
#  'Bild',
#  'keine Wartung geplant',
#  'FÃ¼r dieses GerÃ¤te ist noch keine Wartung vorgesehen.',
#  'Wartung planen',
#  'Bitte geben Sie die notwendigen Informationen an, um die Wartung zu aktualisieren',
#  'Wartungstermin',
#  'Verantwortliche Person',
#  'zeigt alle geplanten Wartungen',
#  'Verantwortlich',
#  'Speichern',
#  'Keine GerÃ¤te fÃ¼r diesen Standort gefunden',
#  'Verantwortliche Person',
#  'Zeigt alle fÃ¼r die Wartung verantwortlichen Personen',
#  'Lieferant',
#  'Seriennummer',
#  'Kaufdatum',
#  'Ja',
#  'Nein',
#  'Unternehmen',
#  'Kontaktperson',
#  'Organisation',
#  'als erledigt markieren',
#  'Bitte markieren Sie die Wartung als abgeschlossen, sobald sie abgeschlossen ist',
#  'Details zur Wartung',
#  'Geplantes Datum',
#  'Ãœbermittlungsdatum',
#  'Noch keine Dokumente hinzugefÃ¼gt',
#  'Dokumente',
#  'Datum der Inbetriebsetzung',
#  'Filter anwenden',
#  'Abbrechen',
#  'Bericht herunterladen',
#  'Erstellung eines AusrÃ¼stungslistenberichts in Arbeit',
#  'Bericht zur AusrÃ¼stungsliste herunterladen',
#  'Erstellung eines AusrÃ¼stungslistenberichts fehlgeschlagen',
#  'kopieren',
#  'GerÃ¤tename',
#  'bearbeiten',
#  'lÃ¶schen',
#  'zusÃ¤tzliche Informationen',
#  'Kategorie',
#  'Kontaktperson',
#  'Datum',
#  'E-Mail',
#  'Letzte Wartung',
#  'Status',
#  'Status',
#  'Standort',
#  'Wartung',
#  'Wartung durch',
#  'Hersteller',
#  'Name',
#  'NÃ¤chste Wartung',
#  'Organisation',
#  'Telefon',
#  'Inbetriebssetzung',
#  'Kaufdatum',
#  'Bemerkungen',
#  'Berichtsname',
#  'Seriennummer',
#  'Unterkategorie',
#  'Lieferant',
#  'pendent',
#  'erledigt',
#  'Erstellt',
#  'letzte Aktualisierung',
#  'Module',
#  'Module erstellen und verwalten',
#  'Module suchen',
#  'Suche Module nach Namen, Thema und Zweck',
#  'Filter',
#  'Modul hinzufÃ¼gen',
#  'Name',
#  'Thema',
#  'Zweck',
#  'erstellt am',
#  'verwerfen',
#  'speichern',
#  'Modul speichern',
#  'Erstellen Sie Ihr Modul',
#  'Zweck des Moduls',
#  'Untergruppe',
#  'Qualifizierung',
#  'Bitten bestimmen Sie den ErfÃ¼llungsgrad',
#  'Frage',
#  'Fragetyp',
#  'Beschreibung',
#  'Beschriftung (links)',
#  'Beschriftung (rechts)',
#  'Kurzer Antworttext',
#  'richtige Antwort markieren',
#  'Option hinzufÃ¼gen',
#  'Hauptgruppe',
#  'von',
#  'Wollen Sie wirklich lÃ¶schen?',
#  'Ja',
#  'Nein',
#  'Modul aktualisieren',
#  'Aktualisieren Sie Ihr Modul',
#  'Maximale Anzahl von Dateien',
#  'maximale DateigrÃ¶sse',
#  'erlaubte Dateiformate',
#  'Datei hinzufÃ¼gen',
#  'Bitte wÃ¤hlen Sie zunÃ¤chst den Zweck',
#  'abbrechen',
#  'Filter anwenden',
#  'Kategorie',
#  'Name der Kategorie',
#  'Name der Unterkategorie',
#  'Kategorie-Ebene',
#  'Unter-Kategorie',
#  'Organisation',
#  'bis',
#  'Organisation',
#  'GrÃ¼nde',
#  'Konto-Aktivierung erfolgreich',
#  'unten Klicken um einzulogen',
#  'Login',
#  'Aktivierung abgelaufen',
#  'nocheinmal einloggen',
#  'Passwort eingeben',
#  'Passwort',
#  'Das Passwort muss mindestens 6 Zeichen lang sein. Muss einen Grossbuchstaben, einen Kleinbuchstaben, ein Sonderzeichen und eine Ziffer enthalten',
#  'Passwort bestÃ¤tigen',
#  'das gleiche Passowrt eingeben',
#  'aktiveren',
#  'APP_PLATFORM_LOGIN_CENTER.TYPE_OPTION_MESSAGE',
#  'Bitte loggen Sie sich in Ihr Konto ein',
#  'Herzlich willkommen!',
#  'APP_PLATFORM_LOGIN_CENTER.TYPE_SIGNUP',
#  'APP_PLATFORM_LOGIN_CENTER.EXTERNAL_LOGIN_OPTION',
#  'APP_PLATFORM_LOGIN_CENTER.LOGIN_OPTION',
#  'Sprache',
#  'E-Mail Adresse',
#  'APP_PLATFORM_LOGIN_CENTER.EMAIL_INVALID',
#  'E-Mail und/oder Passwort stimmen nicht Ã¼berein',
#  'merken',
#  'Passwort vergessen',
#  'APP_PLATFORM_LOGIN_CENTER.EXTERNAL_LOGIN',
#  'nÃ¤chste',
#  '2 Faktor-Code schickt BestÃ¤tigung',
#  'Aktivierungscode',
#  'Der eingegebene Aktivierungscode ist nicht korrekt',
#  'haben Probleme',
#  'nochmals senden',
#  'verifizieren',
#  'Captcha passt nicht',
#  'APP_PLATFORM_LOGIN_CENTER.FIRSTNAME',
#  'APP_PLATFORM_LOGIN_CENTER.LASTNAME',
#  'APP_PLATFORM_LOGIN_CENTER.USER_CREATE_FROM_PERSON_SELF_ACTIVATE',
#  'APP_PLATFORM_LOGIN_CENTER.FOLLOW_THE_LINK_IN_EMAIL',
#  'APP_PLATFORM_LOGIN_CENTER.CONTINUE',
#  'APP_PLATFORM_LOGIN_CENTER.NOT_ALLOWED_TO_SELF_SIGNUP_IN_THIS_SYSTEM',
#  'APP_PLATFORM_LOGIN_CENTER.USER_CREATE_FROM_PERSON_SUCCESS',
#  'APP_PLATFORM_LOGIN_CENTER.GUEST_USER_CREATE_SUCCESS',
#  'E-Mail nicht gefunden',
#  'Passwort zurÃ¼cksetzen',
#  'PasswortÃ¤nderung erfolgreich',
#  'PasswortÃ¤nderungsanfrage, Detail',
#  'Profile auswÃ¤hlen',
#  'Passwort setzen',
#  'ZurÃ¼cksetzen',
#  'eingeloggt',
#  'RÃ¼cksetzung des Passwortes erfolgreich',
#  'Bitte loggen Sie sich in Ihr Konto ein.',
#  'Willkommen bei RiQS',
#  'Angemeldet',
#  'Einverstanden',
#  'nicht einverstanden',
#  'einverstanden',
#  'Ich akzeptiere die Allgemeinen GeschÃ¤ftsbedingungen',
#  'Captcha',
#  'Erstellen und Verwalten von AuftrÃ¤gen',
#  'Status',
#  'aktiv',
#  'weitere hinzufÃ¼gen',
#  'weiteren Auftrag hinzufÃ¼gen',
#  'Alle',
#  'auf anderem Weg erledigt',
#  'Filter anwenden',
#  'genehmigen',
#  'genehmigt',
#  'Aufgabenerledigung bestÃ¤tigt',
#  'zugewiesen am',
#  'Auftrag zuweisen',
#  'Auftrag zuweisen an',
#  'Wochenenden vermeiden',
#  'Abbrechen',
#  'Kategorie',
#  'Kategoriename',
#  'Ursachen',
#  'Organisation',
#  'Bemerkungen',
#  'erledigt',
#  'Ereldigungsstatus',
#  'Auftrag erstellen und zuweisen',
#  'AusfÃ¼hrende Gruppe',
#  'Dokument',
#  'Verantwortliche Person',
#  'erstellen',
#  'geforderter ErfÃ¼llungsgrad',
#  'Auswirkungen /Risiko',
#  'bestimmte Mitarbeiter',
#  'Details',
#  'verwerfen',
#  'erledigt',
#  'Wollen Sie einen weiteren Auftrag mit den gleichen Einstellungen anlegen?',
#  'FÃ¤lligkeit',
#  'E-Mail-Benachrichtigung',
#  'Enddatum',
#  'GerÃ¤te-Bewirtschaftung',
#  'Ereignis / Entwicklung von Umweltfaktoren',
#  'Filter',
#  'Allgemein',
#  'Ihre Antwort',
#  'Bitte geben Sie die notwendigen Informationen des Auftrages ein',
#  'inaktiv',
#  'in Arbeit',
#  'Zuletzt aktualisiert',
#  'E-Mail, wenn nicht erledigt',
#  'AuftrÃ¤ge erstellen und verwalten',
#  'Als wiederkehrende Aufgabe markieren.',
#  'umgesetzte Massnahmen',
#  'Mitglieder',
#  'wenn auf Wochenende fÃ¤llt, auf den nÃ¤chsten Arbeitstag verschieben',
#  'Nicht erledigte AuftrÃ¤ge auf den nÃ¤chsten Tag verschieben',
#  'nÃ¤chste',
#  'nÃ¤chster Auftrag',
#  'Noch keine Antwort',
#  'Keine offenen AuftrÃ¤ge gefunden',
#  'AuftrÃ¤ge',
#  'Ãœbersicht',
#  'pendent',
#  'Prozentsatz',
#  'Bitte definieren Sie den Tag des Monats fÃ¼r die Wiederholung',
#  'Bitte wÃ¤hlen Sie einen Zeitplan',
#  'Bitte bestimmen Sie, wie Sie bei diesem Auftrag informiert werden mÃ¶chten',
#  'Bitte wÃ¤hlen Sie die Kategorie aus',
#  'Bitte wÃ¤hlen Sie die Kategorie des Auftrages aus',
#  'Bitte wÃ¤hlen Sie die Organisation aus',
#  'Bitte wÃ¤hlen Sie die Organisation aus',
#  'Bestimmen Sie, bis wann der Auftrag erledigt werden soll',
#  'Bitte geben Sie an, wann dieser Auftrag wiederholt werden soll',
#  'Bitte wÃ¤hlen Sie die Aufgabenliste aus dem Entwickler aus',
#  'Bitte wÃ¤hlen Sie das Thema aus',
#  'vorheriger Auftrag',
#  'neu zuweisen',
#  'neu zugewiesen',
#  'Auftrag neu zugewiesen',
#  'Wiederholung',
#  'Referenz',
#  'Bemerkungen',
#  'Wiederholung alle',
#  'Wiederholen am',
#  'Wiederholung am Tag',
#  'Auf Standard zurÃ¼cksetzen',
#  'Antwort',
#  'Antworten',
#  'Verantwortlich',
#  'Risiko-Management',
#  'Planung des zugewiesenen Auftrages in Bearbeitung',
#  'Auftrag suchen',
#  'Startdatum',
#  'Status',
#  'Ã¼bermitteln',
#  'Ã¼bermittelt',
#  'Antwort Ã¼bermitteln',
#  'Unterkategorie',
#  'Name der Unterkategorie',
#  'Auftrag',
#  'Auftrags-Liste',
#  'zu erledigende AuftrÃ¤ge',
#  'Auftrags-Erstellung',
#  'Auftrag erfolgreich erstellt',
#  'Auftrags-Erstellung misslungen',
#  'letztmalige Wiederholung',
#  'Aufgaben Fortschritt',
#  'Aufgabe geplant fÃ¼r',
#  'Auftrags-Auswahl',
#  'Trainingsmodul ist allen Mitgliedern der ausfÃ¼hrenden Gruppe zugewiesen. oder',
#  'Ausbidlungsmodul ist zugÃ¤nglich fÃ¼r die ganze Leitung, oder',
#  'Der Auftrag ist allen Mitgliedern der ausfÃ¼hrenden Gruppe zugewiesen oder',
#  'Der Auftrag ist zugÃ¤nglich fÃ¼r die ganze Leitung, oder',
#  'Der Auftrag ist allen Mitgliedern der ausfÃ¼hrenden Gruppe zugewiesen, oder',
#  'Der Auftrag ist zugÃ¤nglich fÃ¼r die ganze Leitung, oder',
#  'Titel',
#  'Thema',
#  'Training',
#  'Trainingsmodul',
#  'aktualisiert durch',
#  'aktualisiert am',
#  'Ansicht fÃ¼r',
#  'Budget',
#  'Bitte nur Zahlen eingeben',
#  'Auftrags-Liste neu zuweisen',
#  'Effektiv',
#  'Kein Risiko gefunden',
#  'Kein Trainingsmodul gefunden',
#  'Bericht herunterladen',
#  'Auftrags-Liste wird gerade erstellt',
#  'Auftrags-Liste herunterladen',
#  'Generierung der Auftrags-Liste fehlgeschlagen',
#  'ein Admin',
#  'Auftrag aktualisieren',
#  'Auftrag editieren',
#  'Aufgaben-Referenz',
#  'ErfÃ¼llungsgrad',
#  'Ã¶ffnen',
#  'Risiko',
#  'fÃ¤llig',
#  'Informationen',
#  'Budget',
#  'Aufgabe aktivieren',
#  'Aufgabe inaktivieren',
#  'Aufgabe editieren',
#  'Aufgaben-Details',
#  'Massnahme',
#  'Risiko-Referenz',
#  'Risiko-Thema',
#  'Risiko zuletzt aktualisiert',
#  'von',
#  'archiviert',
#  'als erledigt markieren',
#  'lÃ¶schen',
#  'WÃ¤hlen Sie aus, was Sie lÃ¶schen mÃ¶chten',
#  'nur zukÃ¼nftige',
#  'Alle AuftrÃ¤ge',
#  'zugewiesen an',
#  'zeigt alle Mitarbeiter, denen dieser Auftrag zugewiesen wurde',
#  'Auftrag suchen',
#  'muss von allen erledigt werden',
#  'auf anderem Weg erledigt',
#  'geprÃ¼ft',
#  'Budget',
#  'Kategorie',
#  'Organisation',
#  'abgeschlossen durch',
#  'erledigt',
#  'erledigt & geprÃ¼ft',
#  'erledigt',
#  'Datum',
#  'fÃ¤llig',
#  'Allgemein',
#  'offen',
#  'pendent / erledigt',
#  'noch nicht abgeschlossen',
#  'neu zugewiesen',
#  'Bemerkungen',
#  'Berichtsname',
#  'verantwortlicher Benutzer',
#  'Risiko-Management',
#  'Status',
#  'Unterkategorie',
#  'Auftrag',
#  'Aufgaben-Typ',
#  'Training',
#  'Risiko-Management',
#  'Risiken',
#  'offene AuftrÃ¤ge',
#  'Risiko Suche',
#  'Risiko anzeigen fÃ¼r',
#  'Zuletzt aktualisiert am',
#  'am',
#  'durch',
#  'Risiko Zuweisung',
#  'Risiken hinzufÃ¼gen, Ã¼berwachen und verwalten',
#  'Risiko hinzufÃ¼gen',
#  'identfiziertes Risiko hinzufÃ¼gen',
#  'Allgemeine Informationen',
#  'Bitte wÃ¤hlen Sie das Thema des Risikos aus',
#  'Thema',
#  'Referenz',
#  'Ereignis / Entwicklung von Umweltfaktoren',
#  'Auswirkungen / Risiko',
#  'Ursachen',
#  'Bewertung (optional)',
#  'Sie kÃ¶nnen die Bewertung fÃ¼r dieses Risiko jetzt oder spÃ¤ter auf der Seite mit den Risikodetails hinzufÃ¼gen',
#  'Bewertung hinzufÃ¼gen',
#  'Bewertung hinzufÃ¼gen fÃ¼r',
#  'Aktualisiere Risiko-Bewertung',
#  'Bitte bewerten Sie dieses Risiko',
#  'Auswirkungen / Risiko',
#  'Wahrscheinlichkeit',
#  'Bewertung',
#  'Zielwert',
#  'verwerfen',
#  'hinzufÃ¼gen',
#  'unbedeutend',
#  'gering',
#  'spÃ¼rbar',
#  'kritisch',
#  'katastrophal',
#  'unwahrscheinlich',
#  'sehr selten',
#  'selten',
#  'mÃ¶glich',
#  'hÃ¤ufig',
#  'vertretbar',
#  'bedingt vertretbar',
#  'nicht vertretbar',
#  'Risikobeurteilung',
#  'Anzeige der Bewertung vom',
#  'Details',
#  'Bewertungen',
#  '3 Thema ?',
#  'Auftrag hinzufÃ¼gen',
#  'nÃ¤chster Auftrag',
#  'vorheriger Auftrag',
#  'vorheriges Risiko',
#  'nÃ¤chstes Risiko',
#  'aktualisiert am',
#  'aktualisiert durch',
#  'es liegt noch keine Bewertung vor',
#  'zeigt alle Bewertungen dieses Risikos',
#  'speichern',
#  'aktualisieren',
#  'Risiko aktualisieren',
#  'Risiko akutalisieren',
#  'Keine Bewertung gefunden',
#  'es liegt noch keine Bewertung dieses Risikos vor',
#  'Kein Risiko gefunden',
#  'mehr',
#  'Ãœbersicht',
#  'Anzahl identifizierter Risiken',
#  'Risiko freigegeben',
#  'Ã¼berprÃ¼ftes Risiko',
#  'pendent',
#  'Bitte Risiko-Kategorie auswÃ¤hlen',
#  'Kategoriename',
#  'Name der Unterkategorie',
#  'bitte, zuerst die Kategorie auswÃ¤hlen',
#  'Bemerkungen',
#  'WÃ¤hlen Sie eine Option',
#  'Bestehende Massnahmen',
#  'Zuordnung hinzugefÃ¼gt',
#  'Zielwert',
#  'Vorgehen',
#  'Risiko freigeben',
#  'Bericht herunterladen',
#  'Risiko-Status',
#  'freigegeben',
#  'freigegeben',
#  'pendent',
#  'Identifiziert',
#  'Fachkraft',
#  'Risiko-Eigner',
#  'identifiziert',
#  'unbewertetes Risiko',
#  'vertretbar',
#  'bedingt vertretbar',
#  'pendente Massnahmen',
#  'Total identifizierte Risiken',
#  'Risiko freigegeben',
#  'Risiko-Ãœbersichtsbericht herunterladen',
#  'kopieren',
#  'lÃ¶schen',
#  'vertretbares Risiko',
#  'bedingt vertretbares Risiko',
#  'nicht vertretbares Risiko',
#  'Total pendente Risiken',
#  'Total freigegebene Risiken',
#  'bedingt vertretbar',
#  'umgesetzte Massnahmen',
#  'Titel der Aufgabe',
#  'Risikodetails',
#  'Information',
#  'hinzugefÃ¼gt von',
#  'abgeschlossen durch',
#  'Risikobericht',
#  'Risiko Name',
#  'Kategorie',
#  'Unterkategorie',
#  'Risiko-Eigner',
#  'Fachkraft',
#  'Status',
#  'freigegeben',
#  'pendent',
#  'aktueller Risikowert',
#  'umgesetzte Massnahmen',
#  'pendente Massnahmen',
#  'Ziel',
#  'Kein aktuelles Ziel',
#  'Ereignis / Entwicklung von Umweltfaktoren',
#  'kein aktuelles Ereignis / keine Ã„nderung der Umweltfaktoren',
#  'Ursache',
#  'keine Ursachen',
#  'Auswirkungen / Risiko',
#  'keine Auswirkungen',
#  'Name der Organisation',
#  'Risikobeurteilung',
#  'Auswirkungen / Risiko',
#  'Wahrscheinlichkeit',
#  'Bewertung',
#  'Risikowert',
#  'umgesetzte Massnahmen',
#  'keine aktuelle Massnahme',
#  'geplante Massnahmen',
#  'keine zukÃ¼nftigen Massnahmen',
#  'Bemerkungen',
#  'keine Bemerkungen',
#  'Vorgehen',
#  'Verantwortliche Person',
#  'FÃ¤lligkeitsdatum',
#  'Budget',
#  'Export-Datum',
#  'Risiko vermeiden',
#  'Risiko vermindern',
#  'Risiko Ã¼berwachen',
#  'Risiko akzeptieren',
#  'unbedeutend',
#  'gering',
#  'spÃ¼rbar',
#  'kritisch',
#  'katastrophal',
#  'unwahrscheinlich',
#  'sehr selten',
#  'selten',
#  'mÃ¶glich',
#  'hÃ¤ufig',
#  'vertretbar',
#  'bedingt vertretbar',
#  'nicht vertretbar',
#  'erledigt',
#  'durch',
#  'zugewiesen an',
#  'RisikoÃ¼bersichtsbericht',
#  'vertretbares Risiko',
#  'bedingt vertretbares Risiko',
#  'nicht vertretbares Risiko',
#  'Total identifizierte Risiken',
#  'Total pendente Risiken',
#  'Total freigegebene Risiken',
#  'Zuletzt aktualisiert am',
#  'Risiko Status',
#  'identifiziert',
#  'pendent',
#  'freigegeben',
#  'Wirtschaftlichkeit',
#  '4 Thema',
#  '5 Thema',
#  'Reputation',
#  '1 Thema',
#  'Patientensicherheit',
#  '2 Thema',
#  '6 Thema',
#  '3 Thema',
#  'Mitarbeiter:innen',
#  'Risiko vermeiden',
#  'Risiko vermindern',
#  'Risiko Ã¼berwachen',
#  'Risiko akzeptieren',
#  'Aufgabe geplant fÃ¼r',
#  'Start Datum',
#  'keine Aufgaben gefunden',
#  'Ende Datum',
#  'ErfÃ¼llung',
#  'Minimum',
#  'Maximum',
#  'alle Ã¼berfÃ¤lligen Aufgaben anzeigen',
#  'Thema',
#  'ausgezeichnet',
#  'schlecht',
#  'Antwort speichern',
#  'Bitte geben Sie den ErfÃ¼llungsgrad dieser Aufgabe an',
#  'nÃ¤chste Aufgabe',
#  'vorherige Aufgabe',
#  'Antwort',
#  'Bemerkungen',
#  'Bittel wÃ¤hlen Sie die prÃ¼fende Gruppe aus',
#  'Anzeige der ausfÃ¼hrenden Gruppenmitglieder',
#  'kontrollierter Benutzer',
#  'Mitglied der prÃ¼fenden Gruppe',
#  'Frage beantworten',
#  'Bitte Ã¼berprÃ¼fen Sie die Aufgabe',
#  'Datum der letzten Aktualisierung',
#  'vorgesehener Zeitpunkt',
#  'Unterkategorie',
#  'abbrechen',
#  'Filter anwenden',
#  'Details zur Aufgabe',
#  'Organisation auswÃ¤hlen',
#  'Anzeige der Aufgaben von',
#  'Monitor',
#  'Training',
#  'Aufgabe suchen',
#  'Filter',
#  'Aufgabe zuweisen',
#  'Heutige Aufgaben',
#  'Ãœbersicht',
#  'zuweisen',
#  'bearbeiten Sie die Aufgabe und weisen Sie sie zu',
#  'Aufgaben-Konfiguration',
#  'Auswahl der Aufgabe',
#  'Bitte wÃ¤hlen Sie die Organisation aus.',
#  'Kategorie',
#  'Kategoriename',
#  'Name der Unterkategorie',
#  'Kategorie Ebene',
#  'Organisation',
#  'Bitte wÃ¤hlen Sie die Kategorie der Aufgabe aus.',
#  'Mitglieder der prÃ¼fenden Gruppe',
#  'ausfÃ¼hrende Gruppe',
#  'Die Aufgabe ist fÃ¼r alle Mitglieder der prÃ¼fenden Gruppe zugÃ¤nglich; oder',
#  'Bestimmen Sie die verantwortliche Person fÃ¼r diese Aufgabe',
#  'Mitarbeiter auswÃ¤hlen',
#  'auf Standard zurÃ¼cksetzen',
#  'Bitte wÃ¤hlen Sie das Thema der Aufgabe aus.',
#  'Aufgabenliste',
#  'Bitte wÃ¤hlen Sie die Aufgabenliste aus dem Entwickler aus',
#  'Ãœbermittlungsdatum',
#  'Als wiederkehrende Aufgabe markieren',
#  'Benachrichtigung',
#  'Bitte bestimmen Sie, wie Sie bei dieser Aufgabe informiert werden mÃ¶chten',
#  'Mail wenn Aufgabe nicht geprÃ¼ft wird',
#  'Mail wenn ErfÃ¼llungsgrad unter 100%',
#  'Nicht kontrollierte Aufgabe auf den nÃ¤chsten Tag verschieben',
#  'Bitte wÃ¤hlen Sie die Aufgabe(n) aus, die Sie zuordnen mÃ¶chten',
#  'Aufgabenliste',
#  'Zuletzt aktualisiert am',
#  'Aufgaben',
#  'Beschreibung',
#  'zuweisen',
#  'zurÃ¼ck',
#  'nÃ¤chste',
#  'verwerfen',
#  'Bitte geben Sie an, wann diese Aufgabe wiederholt werden soll',
#  'Intervall',
#  'Wiederholung alle',
#  'Enddatum der Aufgabe',
#  'Wochenenden & Feiertage vermeiden',
#  'Wochenende vermeiden',
#  'Feiertage vermeiden',
#  'wenn auf Wochenende oder Feiertage fÃ¤llt, Aufgabe auf den nÃ¤chsten Arbeitstag verschieben',
#  'wenn auf Feiertag fÃ¤llt, Aufgabe auf den nÃ¤chsten Arbeitstag verschieben',
#  'ungeprÃ¼fte Aufgabe auf nÃ¤chsten Tag verschieben',
#  'Wiederholung Ein',
#  'Bitte legen Sie den jeweiligen Tag des Monats fÃ¼r die Wiederholung fest',
#  'Weitere hinzufÃ¼gen',
#  'Wiederholung am Tag',
#  'Mitglieder',
#  'Aufgabe erfolgreich erstellt',
#  'Aufgabenerstellung fehlgeschlagen',
#  'Aufgabe wurde erstellt',
#  'Terminierung der ausgewÃ¤hlten Aufgabe in Arbeit',
#  'Bitte wÃ¤hlen Sie das Thema aus',
#  'Bitte wÃ¤hlen Sie die Organisation aus',
#  'Bitte wÃ¤hlen Sie die Kategorie aus',
#  'Total gestellter Aufgaben',
#  'ErfÃ¼llungsgrad',
#  'Ã¼berprÃ¼fte Aufgaben',
#  'ErfÃ¼llungsgrad aller kontrollierten Aufgaben',
#  'ErfÃ¼llungsgrad aller unkontrollierten Aufgaben',
#  'nicht Ã¼berprÃ¼fte Aufgaben',
#  'Aufgabe erledigt',
#  'meldender Mitarbeiter',
#  'alle',
#  'kontrollierte Aufgabe',
#  'verbleibende Aufgaben',
#  'wÃ¤hlen Sie eine Option',
#  'Sortieren nach',
#  'Siehe',
#  'alle Aufgaben',
#  'ausgewÃ¤hlte Aufgaben',
#  'Alle anzeigen',
#  'E-Mail-Benachrichtigung',
#  'Aufgabenliste',
#  'Aufgaben Details',
#  'Mail wenn ErfÃ¼llungsgrad unter',
#  'Prozentsatz',
#  'Wollen Sie eine weitere Aufgabe mit den gleichen Einstellungen erstellen?',
#  'Ja',
#  'Nein',
#  'Tag',
#  'Tage',
#  'nicht gesetzt',
#  'Aufgabe kann nur zum geplanten Termin beantwortet werden',
#  'Anzeige aller ausgewÃ¤hlten Aufgaben',
#  'zuletzt aktualisiert am',
#  'Ã¼bermittelt am',
#  'Bitte wÃ¤hlen Sie fÃ¼r die Aufgabe einen Zeitplan',
#  'Eine weitere Aufgabe zuweisen',
#  'Unterkategorie',
#  'aktualisiere Aufgabe',
#  'Aktualisierung',
#  'Konfigurieren und aktualisieren Sie die zugewiesene Aufgabe',
#  'Wiederholen',
#  'Wiederholungstyp',
#  'aktiv',
#  'Datei herunterladen',
#  'Bericht herunterladen',
#  'Prozess-Monitor Report in Arbeit',
#  'Prozess-Monitor Aufgaben Liste in Arbeit',
#  'Erstellung Prozess-Monitor Report fehlgeschlagen',
#  'Erstellung Prozess-Monitor Aufgaben-Liste fehlgeschlagen',
#  'Herunterladen Prozess-Monitor Report',
#  'Herunterladen Aufgaben-Liste',
#  'Dieses Feld ist obligatorisch',
#  'zugewiesene Aufgaben',
#  'ErfÃ¼llungsgrad aller Aufgaben',
#  'ErfÃ¼llungsgrad aller kontrollierten Aufgaben',
#  'unkontrollierte Aufgabe',
#  'ErfÃ¼llungsgrad aller unkontrollierten Aufgaben',
#  'Status',
#  'inaktiv',
#  'Startdatum der Aufgabe',
#  'Benutzer auswÃ¤hlen',
#  'lÃ¶schen',
#  'WÃ¤hlen Sie aus, was Sie lÃ¶schen mÃ¶chten',
#  'nur zukÃ¼nftige Aufgaben',
#  'Kategorie',
#  'Datum',
#  'End-Datum',
#  'Organisation',
#  'Intervall',
#  'Wiederholung',
#  'Berichtsname',
#  'Verantwortlich',
#  'Start-Datum',
#  'Status',
#  'Unterkategorie',
#  'Aufgabe',
#  'Kategorie',
#  'Datum',
#  'Organisation',
#  'Unterkategorie',
#  'Berichtsname',
#  'Aufgabe',
#  'FÃ¼r diese Aufgabe verantwortlicher Benutzer',
#  'ErfÃ¼llungsgrad',
#  'Bemerkung',
#  'Datum und Uhrzeit',
#  'begutachtende Person',
#  'Prozentsatz',
#  'Training',
#  'Trainingsmodul zuweisen',
#  'Filter',
#  'von',
#  'erledigt',
#  'Ã¼bermittelt durch',
#  'Ãœbermttlungsdatum',
#  'kein Ergebnis gefunden',
#  'Sie mÃ¼ssen das Training nochmals wiederholen.',
#  'Training erfolgreich',
#  'es liegt noch kein Ergebnis Ihres Trainings vor - Starten Sie das Trainingsmodul',
#  'Start des Trainings',
#  'Training nach Name, Auftraggeber und Thema suchen',
#  'Anzeige der Ãœbermittlung durch',
#  'fÃ¼r dieses Trainingsmodul',
#  'Erstellen und Verwalten von Trainingsmodulen',
#  'Zeigen der Ihnen zugewiesenen Trainingsmodule',
#  'Trainingsmodul fÃ¼r Ihre Organisation zuweisen',
#  'Bitte Thema der Aufgabe auswÃ¤hlen',
#  'Bitte wÃ¤hlen Sie das Thema des Trainingsmoduls aus',
#  'Thema',
#  'Bitte Aufgabenliste auswÃ¤hlen',
#  'Frageliste',
#  'Bitte zuerst das Thema auswÃ¤hlen',
#  'Management Gruppe',
#  'zugewiesen an',
#  'Trainingsmodul fÃ¼r die gesamte Leitung zugÃ¤nglich, ODER',
#  'Trainingsmodul wird der gesamten AusfÃ¼hrungsgruppe zugewiesen, ODER',
#  'Benutzer auswÃ¤hlen',
#  'Bitte bestimmen Sie das FÃ¤lligkeitsdatum dieses Trainingsmoduls',
#  'FÃ¤lligkeitsdatum',
#  'erstellen',
#  'verwerfen',
#  'zurÃ¼cksetzen',
#  'Teilnehmer',
#  'Titel',
#  'Erstellung Trainingsmodul fehlgeschlagen',
#  'Erstellen des Trainingsmoduls war erfolgreich',
#  'zugewiesen am',
#  'Organisation',
#  'Name',
#  ...]

# %%
Italian=translate_list(German_List, 'it')
print(Italian)
# Out:
# [{'translatedText': 'Aggiungi categoria', 'detectedSourceLanguage': 'de', 'input': 'Kategorie hinzufÃ¼gen'}, {'translatedText': 'mostra categorie e sottocategorie', 'detectedSourceLanguage': 'de', 'input': 'zeigt Kategorien und Unterkategorien'}, {'translatedText': 'crea categoria', 'detectedSourceLanguage': 'de', 'input': 'Kategorie erstellen'}, {'translatedText': 'Fornisci le informazioni necessarie per aggiungere categorie o sottocategorie', 'detectedSourceLanguage': 'de', 'input': 'Bitte geben Sie die notwendigen Informationen zum HinzufÃ¼gen von Kategorien oder Unterkategorien fÃ¼r'}, {'translatedText': 'Nome della categoria', 'detectedSourceLanguage': 'de', 'input': 'Kategoriename'}, {'translatedText': 'gruppo di controllo', 'detectedSourceLanguage': 'de', 'input': 'Kontrollgruppe'}, {'translatedText': 'gruppo esecutivo', 'detectedSourceLanguage': 'de', 'input': 'ausfÃ¼hrende Gruppe'}, {'translatedText': 'assegnare il gruppo', 'detectedSourceLanguage': 'de', 'input': 'Gruppe zuweisen'}, {'translatedText': 'Si prega di assegnare i membri del gruppo per questa categoria.', 'detectedSourceLanguage': 'de', 'input': 'Bitte ordnen Sie die Gruppenmitglieder fÃ¼r diese Kategorie zu.'}, {'translatedText': 'salva categoria', 'detectedSourceLanguage': 'de', 'input': 'Kategorie speichern'}, {'translatedText': 'Aborto', 'detectedSourceLanguage': 'de', 'input': 'Abbrechen'}, {'translatedText': 'Nome della sottocategoria', 'detectedSourceLanguage': 'de', 'input': 'Name der Unterkategorie'}, {'translatedText': 'sottocategoria', 'detectedSourceLanguage': 'de', 'input': 'Unterkategorie'}, {'translatedText': 'Aggiungi sottocategoria', 'detectedSourceLanguage': 'de', 'input': 'Unterkategorie hinzufÃ¼gen'}, {'translatedText': 'di più', 'detectedSourceLanguage': 'de', 'input': 'mehr'}, {'translatedText': 'Mostra categorie', 'detectedSourceLanguage': 'de', 'input': 'Kategorien anzeigen'}, {'translatedText': 'sottocategorie', 'detectedSourceLanguage': 'de', 'input': 'Unter-Kategorien'}, {'translatedText': 'Nessuna sottocategoria aggiunta', 'detectedSourceLanguage': 'de', 'input': 'Keine Unterkategorie hinzugefÃ¼gt'}, {'translatedText': 'Mostra i membri del gruppo di controllo per tutte le categorie', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der prÃ¼fenden Gruppe fÃ¼r alle Kategorie'}, {'translatedText': 'Membri del gruppo di esame', 'detectedSourceLanguage': 'de', 'input': 'Mitglieder der prÃ¼fenden Gruppe'}, {'translatedText': 'Membro del gruppo esecutivo', 'detectedSourceLanguage': 'de', 'input': 'Mitglied der ausfÃ¼hrenden Gruppe'}, {'translatedText': 'Visualizza tutte le sottocategorie di', 'detectedSourceLanguage': 'de', 'input': 'Anzeige aller Unterkategorien von'}, {'translatedText': 'Visualizzazione dei membri del gruppo in esecuzione', 'detectedSourceLanguage': 'de', 'input': 'Anzeige der ausfÃ¼rhenden Gruppenmitglieder'}, {'translatedText': 'Mostra i membri del gruppo in esecuzione per questa sottocategoria', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der ausfÃ¼hrenden Gruppe fÃ¼r diese Unterkategorie'}, {'translatedText': 'Visualizza i membri del gruppo esecutivo della categoria', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der ausfÃ¼hrenden Gruppe der Kategorie an'}, {'translatedText': 'Mostra i membri del gruppo di controllo della categoria', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der prÃ¼fenden Gruppe der Kategorie'}, {'translatedText': 'Nessun membro del gruppo in esecuzione aggiunto', 'detectedSourceLanguage': 'de', 'input': 'Kein Mitglieder der ausfÃ¼hrenden Gruppe hinzugefÃ¼gt'}, {'translatedText': 'Nessun membro del gruppo di controllo aggiunto', 'detectedSourceLanguage': 'de', 'input': 'Kein Mitglied der prÃ¼fenden Gruppe hinzugefÃ¼gt'}, {'translatedText': 'Nessuna categoria aggiunta per questo cliente.', 'detectedSourceLanguage': 'de', 'input': 'Keine Kategorie fÃ¼r diesen Kunden hinzugefÃ¼gt.'}, {'translatedText': 'categoria di aggiornamen ...

# %%
French=translate_list(German_List, 'fr')
print(French)
# Out:
# [{'translatedText': 'Ajouter une catégorie', 'detectedSourceLanguage': 'de', 'input': 'Kategorie hinzufÃ¼gen'}, {'translatedText': 'affiche les catégories et les sous-catégories', 'detectedSourceLanguage': 'de', 'input': 'zeigt Kategorien und Unterkategorien'}, {'translatedText': 'créer une catégorie', 'detectedSourceLanguage': 'de', 'input': 'Kategorie erstellen'}, {'translatedText': 'Veuillez fournir les informations nécessaires pour ajouter des catégories ou des sous-catégories pour', 'detectedSourceLanguage': 'de', 'input': 'Bitte geben Sie die notwendigen Informationen zum HinzufÃ¼gen von Kategorien oder Unterkategorien fÃ¼r'}, {'translatedText': 'Nom de catégorie', 'detectedSourceLanguage': 'de', 'input': 'Kategoriename'}, {'translatedText': 'groupe de contrôle', 'detectedSourceLanguage': 'de', 'input': 'Kontrollgruppe'}, {'translatedText': 'groupe exécutif', 'detectedSourceLanguage': 'de', 'input': 'ausfÃ¼hrende Gruppe'}, {'translatedText': 'affecter un groupe', 'detectedSourceLanguage': 'de', 'input': 'Gruppe zuweisen'}, {'translatedText': 'Veuillez attribuer les membres du groupe pour cette catégorie.', 'detectedSourceLanguage': 'de', 'input': 'Bitte ordnen Sie die Gruppenmitglieder fÃ¼r diese Kategorie zu.'}, {'translatedText': 'enregistrer la catégorie', 'detectedSourceLanguage': 'de', 'input': 'Kategorie speichern'}, {'translatedText': 'Avorter', 'detectedSourceLanguage': 'de', 'input': 'Abbrechen'}, {'translatedText': 'Nom de la sous-catégorie', 'detectedSourceLanguage': 'de', 'input': 'Name der Unterkategorie'}, {'translatedText': 'sous-catégorie', 'detectedSourceLanguage': 'de', 'input': 'Unterkategorie'}, {'translatedText': 'Ajouter une sous-catégorie', 'detectedSourceLanguage': 'de', 'input': 'Unterkategorie hinzufÃ¼gen'}, {'translatedText': 'Suite', 'detectedSourceLanguage': 'de', 'input': 'mehr'}, {'translatedText': 'Afficher les catégories', 'detectedSourceLanguage': 'de', 'input': 'Kategorien anzeigen'}, {'translatedText': 'sous-catégories', 'detectedSourceLanguage': 'de', 'input': 'Unter-Kategorien'}, {'translatedText': 'Aucune sous-catégorie ajoutée', 'detectedSourceLanguage': 'de', 'input': 'Keine Unterkategorie hinzugefÃ¼gt'}, {'translatedText': 'Affiche les membres du groupe de vérification pour toutes les catégories', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der prÃ¼fenden Gruppe fÃ¼r alle Kategorie'}, {'translatedText': 'Membres du groupe examinateur', 'detectedSourceLanguage': 'de', 'input': 'Mitglieder der prÃ¼fenden Gruppe'}, {'translatedText': 'Membre du groupe exécutif', 'detectedSourceLanguage': 'de', 'input': 'Mitglied der ausfÃ¼hrenden Gruppe'}, {'translatedText': 'Afficher toutes les sous-catégories de', 'detectedSourceLanguage': 'de', 'input': 'Anzeige aller Unterkategorien von'}, {'translatedText': 'Affichage des membres du groupe d&#39;exécution', 'detectedSourceLanguage': 'de', 'input': 'Anzeige der ausfÃ¼rhenden Gruppenmitglieder'}, {'translatedText': 'Affiche les membres du groupe d&#39;exécution pour cette sous-catégorie', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der ausfÃ¼hrenden Gruppe fÃ¼r diese Unterkategorie'}, {'translatedText': 'Affiche les membres du groupe de direction de la catégorie', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der ausfÃ¼hrenden Gruppe der Kategorie an'}, {'translatedText': 'Affiche les membres du groupe de contrôle de la catégorie', 'detectedSourceLanguage': 'de', 'input': 'Zeigt die Mitglieder der prÃ¼fenden Gruppe der Kategorie'}, {'translatedText': 'Aucun membre du groupe d&#39;exécution ajouté', 'detectedSourceLanguage': 'de', 'input': 'Kein Mitglieder der ausfÃ¼hrenden Gruppe hinzugefÃ¼gt'}, {'translatedText': 'Aucun membre du groupe de vérification ajouté', 'detectedSourceLanguage': 'de', 'input': 'Kein Mitglied der prÃ¼fenden Gruppe hinzugefÃ¼gt'}, {'translatedText': 'Aucune catégorie ajoutée pour ce client.', 'detectedSourceLanguage': 'de', 'input': 'Keine Kategorie fÃ¼r diesen Kunden  ...

# %%
import json

# %%
keys = French[0].keys()

with open('french.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(French)

# %%
keys = Italian[0].keys()

with open('italian.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(Italian)
